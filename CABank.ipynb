# %%
import pylangacq as pla

# %%
north = pla.read_chat('datasets/CABank/engn/*.cha')

# %%
north.utterances()
# Out:
# [('LENO', "So you don't need to go borrow equipment from anybody to +/."),
#  ('LENO', 'to do the feet ?'),
#  ('LENO', '⌈ Do the hooves ⌉ ?'),
#  ('LYNN', "⌊ ⌋ ΫWell we're gonna have to find somewhere to get somethingΫ ."),
#  ('DORI', 'So ⌈ Mae- ⌉ +...'),
#  ('LYNN', "⌊ I'm gonna ⌋ +..."),
#  ('DORI', '⌈Mae Lynne XX ⌉ .'),
#  ('LYNN',
#   "⌊&=in We're not⌋ gonna do the feet today I'm gonna wait till like early in the morning: to do those cause y- +/."),
#  ('LYNN', 'I mean you get s:o ti:red .'),
#  ('LYNN', 'n- you just it takes ʔuh +/.'),
#  ('LYNN',
#   "well it takes me longer than most people cause you know I'm not as stro:ng and and I'm not as good as like somebody that would do it all the ti:me ."),
#  ('LYNN', 'You know .'),
#  ('LYNN', 'I mean ʔuh Oh +/.'),
#  ('LYNN',
#   "I mean I trim horses: and stuff like that but I mean I'm not like I'm no:t uh: I don't know how to say it ."),
#  ('LYNN', 'But you know they do it for a living .'),
#  ('LYNN',
# ...
